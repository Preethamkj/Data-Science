# %% [markdown]
# # File Handling

# %%
# Whether in real life or in the digital world - we use files to store data. Files are a collection of data which can be
# stored, extracted and manipulated. 

# Python allows us to handle two types of files:

# Text - where the information is stored as a sequence of characters
# Binary - where the data is stored in Bytes(8 bit sequences)

# Internally, even text in text files is stored as bytes. However, we can operate directly in text form on Text files unlike
# binary files which are used to store text, images, video, audio and other types of files. 

# Each line of code in a file terminates with an End Of Line (EOL) character, '\n' by default in Python, but different
# for different operating systems (e.g. '\r\n' in Windows. Internally, Python will change the '\r\n' to '\n' when it is 
# run. 

# Previously End of File markers were used to indicate the End Of File. As per my understanding, since a couple of decades
# now, end of file is handled by most languages by checking the length. You may still encounter the 'End Of File (EOF)' 
# word but as far as I know - there is no particular marker any more.

# %%
# When opening a file for performing operations on them in Python - we open the file characters specifying what operations
# we are permitting to be performed on the file at the time of opening. This is called the 'mode'

# %%
# Operations permitted  Text Mode  Binary Mode  Handle Position     Notes

# read only             'r'        'rb'         Beginning of file   Default mode of file opening. If file does not exist, 
#                                                                   raises an I/O error.
# read and write        'r+'       'rb+'        Beginning of file   If file does not exist, raises an I/O error. By default,
#                                                                   any write operations are performed at beginning of file.
# write only            'w'        'wb'         Beginning of file   If file exists, truncates file(deletes all contents)
#                                                                   else creates a file for writing into
# write and read        'w+'       'wb+'        Beginning of file   If file exists, truncates file(deletes all contents)
#                                                                   else creates a file for writing into
# append                'a'        'ab'         End of file         If file does not exist, creates file. New data 
#                                                                   will be written at end of file. 
# append and read       'a+'       'ab+'        End of file         If file does not exist, creates file.

# Exclusive creation     'x'        'xb'        Beginning of file   Opens a file for exclusive creation(new file). If 
#                                                                   the file already exists raises an error. 
# Text mode              't'                    Beginning of file   Default mode. You could say, a file without mode
#                                                                   specified opens a file in Text mode for reading (both
#                                                                   are defaults)

# Please remember that handle(cursor) position mentioned above are Default positions. However, once operations have been 
# performed and cursor has been moved - write, read operations are performed from the current cursor position.

# %%
# To open a file we use the open function with the following syntax:

#<variable_name> = open(file_name, mode)

f = open('animal_jokes.txt', 'r')
print(f)
f.close()
# Out:
# <_io.TextIOWrapper name='animal_jokes.txt' mode='r' encoding='cp1252'>

# %%
import os
os.getcwd()
# os.chdir('C:\\Users\Sony\Downloads\Python study material\Python file handling')
# Out:
# 'C:\\Users\\Sony\\Downloads\\Python study material\\Python file handling'

# %%
f = open('animal_jokes.txt', 'r')
for x in f.readlines():
    print(x)
f.close()
# Out:
# Q: What do you call a sleeping bull?
#
#
#
# A: A bull-dozer.
#
#
#
# Q: How does a lion greet the other animals in the field?
#
#
#
# A: Pleased to eat you.
#
#
#
# Q: What did the farmer call the cow that had no milk?
#
#
#
# A: An udder failure.
#
#
#
# Q: Why do gorillas have big nostrils?
#
#
#
# A: Because they have big fingers!
#
#
#
# Q: What do you get from a pampered cow?
#
#
#
# A: Spoiled milk.
#
#
#
# Q: Why are teddy bears never hungry?
#
#
#
# A: They are always stuffed!
#
#
#
# Q: Why do fish live in salt water?
#
#
#
# A: Because pepper makes them sneeze!
#
#
#
# Q: What do you get from a pampered cow?
#
#
#
# A: Spoiled milk.
#
#
#
# Q: Where do polar bears vote?
#
#
#
# A: The North Poll
#
#
#
# Q: Why did the snake cross the road?
#
#
#
# A: To get to the other ssssssside!
#
#
#
# Q: Why are fish so smart?
#
#
#
# A: Because they live in schools.
#
#
#
# Q: What fish only swims at night?
#
#
#
# A: A starfish!
#
#
#
# Q: Why is a fish easy to weigh?
#
#
#
# A: Because it has its own scales!
#
#
#
# Q: What do you get when a chicken lays an egg on top of a barn?
#
#
#
# A: An eggroll!
#
#
#
# Q: Why didn't the chicken cross the road?
#
#
#
# A: Because there was a KFC on the other side!
#
#
#
# Q: Why did the chicken cross the road?
#
#
#
# A: To show everyone he wasn't chicken!
#
#
#
# Q: Why did the lion spit out the clown?
#
#
#
# A: Because he tasted funny!
#
#
#
# Q: What animals are on legal documents?
#
#
#
# A: Seals!
#
#
#
# Q: What do you get when you cross a snake and a pie?
#
#
#
# A: A pie-thon!
#
#
#
# Q: What did the buffalo say to his son when he went away on a trip?
#
#
#
# A: Bison!
#
#
#
# Q: How do bees get to school?
#
#
#
# A: By school buzz!
#
#
#
# Q: What do you call a bear with no ears?
#
#
#
# A: B!

# %%
import os

# %%
# The open function takes several parameters. Some of these are:
#1. File name as string - mandatory
#2. Mode - optional. If not specified opens as a text file in read only mode. 
#3. Buffer size - optional - Default is system dependent (usually 4096 or 8192 bytes). 0 means no buffering, 1 means until
# new line. Otherwise buffersize can be specified.
#4. Encoding - Optional Specifies encoding (Unicode - <UTF8,UTF16, UTF32>, ascii, cp1252 etc.)
#5. Errors - Optional - 
#   'strict’ (Default) - raises an UnicodeError exception on failure
#   ‘backslashreplace’ - the unencodable character is replaced by a backslash
#   ‘ignore’ - the unencodable character is ignored
#   ‘namereplace’ - the unencodable character is replaced by its name
#   ‘replace’ - the unencodable character is replaced by questionmark
#   ‘xmlcharrefreplace’ - the unencodable character is replaced by an xml characterine

# Buffering is storing the information from the input(writing to file) into a buffer and not directly sending it to the file
# Therefore, if 1 is specified as the buffer, then input is written to file once a newline is reached. If a buffer size of
# 500 is specified, when the buffer is full, input is written to file. If 0 is specified, then buffering is off and files
# are written directly to the file. By default, writing to the file happens when file object is closed(removed from
# temporary memory).

# It is useful when using large file sizes with high latency (i.e. input from source is slow, then with buffering the 
# program has to make fewer system calls to write and program speed is faster). On the other hand, working with large file
# sizes with fast streaming data may overflow the buffer causing a system issue (like a crash).

# The effects of buffering will not be visible until we have huge file sizes and/or latency - therefore, we shall skip 
# examples of buffering parameter.

#Encoding and errors - parameters are the same as for bytes objects.

# %%
# We need to open the file saved on our hard disk in primary(RAM) memory for working on the file. Therefore, the need to 
# specify a variable to create the file object and perform operations. Several methods can now be applied to this file
# object

# %%
# open files need to be closed with the close function using the following syntax:

# <variable_name>.close()

# However, to ensure that in case of any errors that data is not lost or files do not get corrupted (since we have not
# closed the file properly), it is good practice to build in exception handling as follows : 

f = open('animal_jokes.txt', 'r')
try:
    print(f.read())
finally:
    f.close()
# Out:
# Q: What do you call a sleeping bull?
#
# A: A bull-dozer.
#
# Q: How does a lion greet the other animals in the field?
#
# A: Pleased to eat you.
#
# Q: What did the farmer call the cow that had no milk?
#
# A: An udder failure.
#
# Q: Why do gorillas have big nostrils?
#
# A: Because they have big fingers!
#
# Q: What do you get from a pampered cow?
#
# A: Spoiled milk.
#
# Q: Why are teddy bears never hungry?
#
# A: They are always stuffed!
#
# Q: Why do fish live in salt water?
#
# A: Because pepper makes them sneeze!
#
# Q: What do you get from a pampered cow?
#
# A: Spoiled milk.
#
# Q: Where do polar bears vote?
#
# A: The North Poll
#
# Q: Why did the snake cross the road?
#
# A: To get to the other ssssssside!
#
# Q: Why are fish so smart?
#
# A: Because they live in schools.
#
# Q: What fish only swims at night?
#
# A: A starfish!
#
# Q: Why is a fish easy to weigh?
#
# A: Because it has its own scales!
#
# Q: What do you get when a chicken lays an egg on top of a barn?
#
# A: An eggroll!
#
# Q: Why didn't the chicken cross the road?
#
# A: Because there was a KFC on the other side!
#
# Q: Why did the chicken cross the road?
#
# A: To show everyone he wasn't chicken!
#
# Q: Why did the lion spit out the clown?
#
# A: Because he tasted funny!
#
# Q: What animals are on legal documents?
#
# A: Seals!
#
# Q: What do you get when you cross a snake and a pie?
#
# A: A pie-thon!
#
# Q: What did the buffalo say to his son when he went away on a trip?
#
# A: Bison!
#
# Q: How do bees get to school?
#
# A: By school buzz!
#
# Q: What do you call a bear with no ears?
#
# A: B!

# %%
#An alternate way to open files is with the 'with' keyword which opens a context manager. Internally, the context manager
# calls the __enter__ constructor and open the files with this context and upon completing the execution automatically calls
# the __exit__ constructor to close the file. 

with open('animal_jokes.txt', 'r') as f:
    for x in f.readlines(50):
        print(x)
        
print(f.closed)
# Out:
# True

# %%
# As you can notice the file has already been closed.

# %%
f = open('animal_jokes.txt', 'r')
for x in f.readlines(50):
    print(x)
    
print(f.closed)

print(f'Closing file object, {f.close()}')

print(f.closed)
# Out:
# Q: What do you call a sleeping bull?
#
# A: A bull-dozer.
#
# False
# Closing file object, None
# True

# %%
# Opening file without default mode. 

with open('animal_jokes.txt') as f:
    data = f.read(200)
    print(data)
    f.write('XYZ')
# Out:
# No more animal jokes
#
# ping bull?
# A: A bull-dozer.
#
# Q: How does a lion greet the other animals in the field?
# A: Pleased to eat you.
#
# Q: What did the farmer call the cow that had no milk?
# A: An udder f
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Input In [112], in <cell line: 3>()
#       4 data = f.read(200)
#       5 print(data)
# ----> 6 f.write('XYZ')
#
# UnsupportedOperation: not writable

# %%
# As we can see a text file with read only permissions has been opened which when we tried to write to gave us an
# UnsupportedOperation error : 'not writable'

# %%
with open('animal_jokes.txt', 'r') as f:
    for x in f.readlines():
        print(x)
# Out:
# Q: What do you call a sleeping bull?
#
# A: A bull-dozer.
#
#
#
# Q: How does a lion greet the other animals in the field?
#
# A: Pleased to eat you.
#
#
#
# Q: What did the farmer call the cow that had no milk?
#
# A: An udder failure.
#
#
#
# Q: Why do gorillas have big nostrils?
#
# A: Because they have big fingers!
#
#
#
# Q: What do you get from a pampered cow?
#
# A: Spoiled milk.
#
#
#
# Q: Why are teddy bears never hungry?
#
# A: They are always stuffed!
#
#
#
# Q: Why do fish live in salt water?
#
# A: Because pepper makes them sneeze!
#
#
#
# Q: What do you get from a pampered cow?
#
# A: Spoiled milk.
#
#
#
# Q: Where do polar bears vote?
#
# A: The North Poll
#
#
#
# Q: Why did the snake cross the road?
#
# A: To get to the other ssssssside!
#
#
#
# Q: Why are fish so smart?
#
# A: Because they live in schools.
#
#
#
# Q: What fish only swims at night?
#
# A: A starfish!
#
#
#
# Q: Why is a fish easy to weigh?
#
# A: Because it has its own scales!
#
#
#
# Q: What do you get when a chicken lays an egg on top of a barn?
#
# A: An eggroll!
#
#
#
# Q: Why didn't the chicken cross the road?
#
# A: Because there was a KFC on the other side!
#
#
#
# Q: Why did the chicken cross the road?
#
# A: To show everyone he wasn't chicken!
#
#
#
# Q: Why did the lion spit out the clown?
#
# A: Because he tasted funny!
#
#
#
# Q: What animals are on legal documents?
#
# A: Seals!
#
#
#
# Q: What do you get when you cross a snake and a pie?
#
# A: A pie-thon!
#
#
#
# Q: What did the buffalo say to his son when he went away on a trip?
#
# A: Bison!
#
#
#
# Q: How do bees get to school?
#
# A: By school buzz!
#
#
#
# Q: What do you call a bear with no ears?
#
# A: B!

# %%
with open('animal_jokes.txt', 'r') as f:
    f.write('\nXYZ')
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Input In [30], in <cell line: 1>()
#       1 with open('animal_jokes.txt', 'r') as f:
# ----> 2     f.write('\nXYZ')
#
# UnsupportedOperation: not writable

# %%
# As with default mode (i.e without specifying 'r', we cannot write to the file)

# %%
with open('animal_jokes.txt', 'r+') as f:
    f.write('\nXYZ')

# %%
with open('animal_jokes.txt', 'r') as f:
    for x in f.readlines():
        print(x)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 with open('animal_jokes.txt', 'r') as f:
#       2     for x in f.readlines():
#       3         print(x)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'animal_jokes.txt'

# %%
# opening files in write only mode. 

with open('animal_jokes.txt', 'w') as f:
    f.write('\nXYZ')

# %%
with open('animal_jokes.txt', 'r') as f:
    for x in f.readlines():
        print(x)
# Out:
# Q: What do you call a sleeping bull?
#
# A: A bull-dozer.
#
#
#
# Q: How does a lion greet the other animals in the field?
#
# A: Pleased to eat you.
#
#
#
# Q: What did the farmer call the cow that had no milk?
#
# A: An udder failure.
#
#
#
# Q: Why do gorillas have big nostrils?
#
# A: Because they have big fingers!
#
#
#
# Q: What do you get from a pampered cow?
#
# A: Spoiled milk.
#
#
#
# Q: Why are teddy bears never hungry?
#
# A: They are always stuffed!
#
#
#
# Q: Why do fish live in salt water?
#
# A: Because pepper makes them sneeze!
#
#
#
# Q: What do you get from a pampered cow?
#
# A: Spoiled milk.
#
#
#
# Q: Where do polar bears vote?
#
# A: The North Poll
#
#
#
# Q: Why did the snake cross the road?
#
# A: To get to the other ssssssside!
#
#
#
# Q: Why are fish so smart?
#
# A: Because they live in schools.
#
#
#
# Q: What fish only swims at night?
#
# A: A starfish!
#
#
#
# Q: Why is a fish easy to weigh?
#
# A: Because it has its own scales!
#
#
#
# Q: What do you get when a chicken lays an egg on top of a barn?
#
# A: An eggroll!
#
#
#
# Q: Why didn't the chicken cross the road?
#
# A: Because there was a KFC on the other side!
#
#
#
# Q: Why did the chicken cross the road?
#
# A: To show everyone he wasn't chicken!
#
#
#
# Q: Why did the lion spit out the clown?
#
# A: Because he tasted funny!
#
#
#
# Q: What animals are on legal documents?
#
# A: Seals!
#
#
#
# Q: What do you get when you cross a snake and a pie?
#
# A: A pie-thon!
#
#
#
# Q: What did the buffalo say to his son when he went away on a trip?
#
# A: Bison!
#
#
#
# Q: How do bees get to school?
#
# A: By school buzz!
#
#
#
# Q: What do you call a bear with no ears?
#
# A: B!

# %%
with open('animal_jokes.txt', 'w') as f:
    for x in f.readlines():
        print(x)
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Input In [55], in <cell line: 1>()
#       1 with open('animal_jokes.txt', 'w') as f:
# ----> 2     for x in f.readlines():
#       3         print(x)
#
# UnsupportedOperation: not readable

# %%
# Note the not readable error.

# %%
with open('animal_jokes.txt', 'w+') as f:
    for x in f.readlines():
        print(x)

# %%
# Note how there is no output - because w and w+ erase the contents of the file when opening in these modes. Therefore in
# the second example also we have no content to read.

# %%
# Re-writing the text to the animals_jokes file using multiple with open

with open('animal_jokes.txt', 'w+') as aj, open('animal_jokes_Copy.txt', 'r') as ajCopy:
    data = ajCopy.readlines()
    aj.writelines(data)

# %%
#Write mode to create a file
import os
os.getcwd()
# os.chdir('C:\\Users\Sony\Downloads\Python study material\Python file handling')
# Out:
# 'C:\\Users\\Sony\\Downloads\\Python study material\\Python file handling'

# %%
with open('New_file.txt', 'w') as nf:
    nf.writelines('This is a new file')

# %%
with open('New_file.txt', 'r') as nf:
    for x in nf:
        print(x)
# Out:
# This is a new file

# %%
# w+ mode to create a file
with open('New_file2.txt', 'w+') as nf:
    nf.write('2nd new file')

# %%
with open('New_file2.txt', 'r') as nf:
    for x in nf:
        print(x)
# Out:
# 2nd new file

# %%
#Append mode and append+ mode.

# %%
with open('animal_jokes.txt', 'a') as f:
    f.write('\nABC')

# %%
with open('animal_jokes.txt', 'r') as f:
    for x in f.readlines():
        print(x)
# Out:
# Q: What do you call a sleeping bull?
#
# A: A bull-dozer.
#
#
#
# Q: How does a lion greet the other animals in the field?
#
# A: Pleased to eat you.
#
#
#
# Q: What did the farmer call the cow that had no milk?
#
# A: An udder failure.
#
#
#
# Q: Why do gorillas have big nostrils?
#
# A: Because they have big fingers!
#
#
#
# Q: What do you get from a pampered cow?
#
# A: Spoiled milk.
#
#
#
# Q: Why are teddy bears never hungry?
#
# A: They are always stuffed!
#
#
#
# Q: Why do fish live in salt water?
#
# A: Because pepper makes them sneeze!
#
#
#
# Q: What do you get from a pampered cow?
#
# A: Spoiled milk.
#
#
#
# Q: Where do polar bears vote?
#
# A: The North Poll
#
#
#
# Q: Why did the snake cross the road?
#
# A: To get to the other ssssssside!
#
#
#
# Q: Why are fish so smart?
#
# A: Because they live in schools.
#
#
#
# Q: What fish only swims at night?
#
# A: A starfish!
#
#
#
# Q: Why is a fish easy to weigh?
#
# A: Because it has its own scales!
#
#
#
# Q: What do you get when a chicken lays an egg on top of a barn?
#
# A: An eggroll!
#
#
#
# Q: Why didn't the chicken cross the road?
#
# A: Because there was a KFC on the other side!
#
#
#
# Q: Why did the chicken cross the road?
#
# A: To show everyone he wasn't chicken!
#
#
#
# Q: Why did the lion spit out the clown?
#
# A: Because he tasted funny!
#
#
#
# Q: What animals are on legal documents?
#
# A: Seals!
#
#
#
# Q: What do you get when you cross a snake and a pie?
#
# A: A pie-thon!
#
#
#
# Q: What did the buffalo say to his son when he went away on a trip?
#
# A: Bison!
#
#
#
# Q: How do bees get to school?
#
# A: By school buzz!
#
#
#
# Q: What do you call a bear with no ears?
#
# A: B!
#
# ABC

# %%
with open('animal_jokes.txt', 'a') as f:
    for x in f.readlines():
        print(x)
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Input In [87], in <cell line: 1>()
#       1 with open('animal_jokes.txt', 'a') as f:
# ----> 2     for x in f.readlines():
#       3         print(x)
#
# UnsupportedOperation: not readable

# %%
# Note how when opened in 'a' mode - file is not readable.

# %%
with open('animal_jokes.txt', 'a+') as f:
    for x in f.readlines():
        print(x)

# %%
# Note no output since the cursor is at end of file.

# %%
with open('animal_jokes.txt', 'a+') as f:
    f.seek(0)
    for x in f.readlines():
        print(x)

# %%
# Before we go on to the binary file types in Python, let us study the methods available on file objects in Python.

# %%
#Method          Description
# close()        Closes the file
# detach()       Returns the separated raw stream from the buffer
# fileno()       Returns a number that represents the stream, from the operating system's perspective
# flush()        Flushes the internal buffer
# isatty()       Returns whether the file stream is interactive or not
# read()         Returns the file content
# readable()     Returns whether the file stream can be read or not
# readline()     Returns one line from the file
# readlines()    Returns a list of lines from the file
# seek()         Change the file position
# seekable()     Returns whether the file allows us to change the file position
# tell()         Returns the current file position
# truncate()     Resizes the file to a specified size
# writable()     Returns whether the file can be written to or not
# write()        Writes the specified string to the file
# writelines()   Writes a list of strings to the file

# %%
# Attributes:

# closed - Returns True if the file is closed and False when the file is open.
# encoding - Encoding used for the file.
# mode - Value of mode parameter.
# name: If the file object was created using open(), the name of the file.
# newlines: A file object that has been opened in universal newline mode has this attribute which reflects the newline
# convention used in the file. The value for this attribute are “\r”, “\n”, “\r\n”, None or a tuple containing all the
# newline types seen.
# softspace: It is a boolean that indicates whether a space character needs to be printed before another value when using the print statement.

# %%
# close() function call and close attribute
f = open('animal_jokes.txt', 'r')
print(f.closed)
f.close()
print(f.closed)
# Out:
# False
# True

# %%
#Note - close() function call closes the file while closed attribute returns True or False indicating the state of the 
# file object.

# %%
# read method - extracts the contents of the file character by character. It can take one parameter, the size (characters or
# bytes) to be read.

# %%
with open('animal_jokes.txt', 'r') as f:
    for x in f.read():
        print(x)
# Out:
# Q
# :
#
# W
# h
# a
# t
#
# d
# o
#
# y
# o
# u
#
# c
# a
# l
# l
#
# a
#
# s
# l
# e
# e
# p
# i
# n
# g
#
# b
# u
# l
# l
# ?
#
#
# A
# :
#
# A
#
# b
# u
# l
# l
# -
# d
# o
# z
# e
# r
# .
#
#
#
#
# Q
# :
#
# H
# o
# w
#
# d
# o
# e
# s
#
# a
#
# l
# i
# o
# n
#
# g
# r
# e
# e
# t
#
# t
# h
# e
#
# o
# t
# h
# e
# r
#
# a
# n
# i
# m
# a
# l
# s
#
# i
# n
#
# t
# h
# e
#
# f
# i
# e
# l
# d
# ?
#
#
# A
# :
#
# P
# l
# e
# a
# s
# e
# d
#
# t
# o
#
# e
# a
# t
#
# y
# o
# u
# .
#
#
#
#
# Q
# :
#
# W
# h
# a
# t
#
# d
# i
# d
#
# t
# h
# e
#
# f
# a
# r
# m
# e
# r
#
# c
# a
# l
# l
#
# t
# h
# e
#
# c
# o
# w
#
# t
# h
# a
# t
#
# h
# a
# d
#
# n
# o
#
# m
# i
# l
# k
# ?
#
#
# A
# :
#
# A
# n
#
# u
# d
# d
# e
# r
#
# f
# a
# i
# l
# u
# r
# e
# .
#
#
#
#
# Q
# :
#
# W
# h
# y
#
# d
# o
#
# g
# o
# r
# i
# l
# l
# a
# s
#
# h
# a
# v
# e
#
# b
# i
# g
#
# n
# o
# s
# t
# r
# i
# l
# s
# ?
#
#
# A
# :
#
# B
# e
# c
# a
# u
# s
# e
#
# t
# h
# e
# y
#
# h
# a
# v
# e
#
# b
# i
# g
#
# f
# i
# n
# g
# e
# r
# s
# !
#
#
#
#
# Q
# :
#
# W
# h
# a
# t
#
# d
# o
#
# y
# o
# u
#
# g
# e
# t
#
# f
# r
# o
# m
#
# a
#
# p
# a
# m
# p
# e
# r
# e
# d
#
# c
# o
# w
# ?
#
#
# A
# :
#
# S
# p
# o
# i
# l
# e
# d
#
# m
# i
# l
# k
# .
#
#
#
#
# Q
# :
#
# W
# h
# y
#
# a
# r
# e
#
# t
# e
# d
# d
# y
#
# b
# e
# a
# r
# s
#
# n
# e
# v
# e
# r
#
# h
# u
# n
# g
# r
# y
# ?
#
#
# A
# :
#
# T
# h
# e
# y
#
# a
# r
# e
#
# a
# l
# w
# a
# y
# s
#
# s
# t
# u
# f
# f
# e
# d
# !
#
#
#
#
# Q
# :
#
# W
# h
# y
#
# d
# o
#
# f
# i
# s
# h
#
# l
# i
# v
# e
#
# i
# n
#
# s
# a
# l
# t
#
# w
# a
# t
# e
# r
# ?
#
#
# A
# :
#
# B
# e
# c
# a
# u
# s
# e
#
# p
# e
# p
# p
# e
# r
#
# m
# a
# k
# e
# s
#
# t
# h
# e
# m
#
# s
# n
# e
# e
# z
# e
# !
#
#
#
#
# Q
# :
#
# W
# h
# a
# t
#
# d
# o
#
# y
# o
# u
#
# g
# e
# t
#
# f
# r
# o
# m
#
# a
#
# p
# a
# m
# p
# e
# r
# e
# d
#
# c
# o
# w
# ?
#
#
# A
# :
#
# S
# p
# o
# i
# l
# e
# d
#
# m
# i
# l
# k
# .
#
#
#
#
# Q
# :
#
# W
# h
# e
# r
# e
#
# d
# o
#
# p
# o
# l
# a
# r
#
# b
# e
# a
# r
# s
#
# v
# o
# t
# e
# ?
#
#
# A
# :
#
# T
# h
# e
#
# N
# o
# r
# t
# h
#
# P
# o
# l
# l
#
#
#
#
# Q
# :
#
# W
# h
# y
#
# d
# i
# d
#
# t
# h
# e
#
# s
# n
# a
# k
# e
#
# c
# r
# o
# s
# s
#
# t
# h
# e
#
# r
# o
# a
# d
# ?
#
#
# A
# :
#
# T
# o
#
# g
# e
# t
#
# t
# o
#
# t
# h
# e
#
# o
# t
# h
# e
# r
#
# s
# s
# s
# s
# s
# s
# s
# i
# d
# e
# !
#
#
#
#
# Q
# :
#
# W
# h
# y
#
# a
# r
# e
#
# f
# i
# s
# h
#
# s
# o
#
# s
# m
# a
# r
# t
# ?
#
#
# A
# :
#
# B
# e
# c
# a
# u
# s
# e
#
# t
# h
# e
# y
#
# l
# i
# v
# e
#
# i
# n
#
# s
# c
# h
# o
# o
# l
# s
# .
#
#
#
#
# Q
# :
#
# W
# h
# a
# t
#
# f
# i
# s
# h
#
# o
# n
# l
# y
#
# s
# w
# i
# m
# s
#
# a
# t
#
# n
# i
# g
# h
# t
# ?
#
#
# A
# :
#
# A
#
# s
# t
# a
# r
# f
# i
# s
# h
# !
#
#
#
#
# Q
# :
#
# W
# h
# y
#
# i
# s
#
# a
#
# f
# i
# s
# h
#
# e
# a
# s
# y
#
# t
# o
#
# w
# e
# i
# g
# h
# ?
#
#
# A
# :
#
# B
# e
# c
# a
# u
# s
# e
#
# i
# t
#
# h
# a
# s
#
# i
# t
# s
#
# o
# w
# n
#
# s
# c
# a
# l
# e
# s
# !
#
#
#
#
# Q
# :
#
# W
# h
# a
# t
#
# d
# o
#
# y
# o
# u
#
# g
# e
# t
#
# w
# h
# e
# n
#
# a
#
# c
# h
# i
# c
# k
# e
# n
#
# l
# a
# y
# s
#
# a
# n
#
# e
# g
# g
#
# o
# n
#
# t
# o
# p
#
# o
# f
#
# a
#
# b
# a
# r
# n
# ?
#
#
# A
# :
#
# A
# n
#
# e
# g
# g
# r
# o
# l
# l
# !
#
#
#
#
# Q
# :
#
# W
# h
# y
#
# d
# i
# d
# n
# '
# t
#
# t
# h
# e
#
# c
# h
# i
# c
# k
# e
# n
#
# c
# r
# o
# s
# s
#
# t
# h
# e
#
# r
# o
# a
# d
# ?
#
#
# A
# :
#
# B
# e
# c
# a
# u
# s
# e
#
# t
# h
# e
# r
# e
#
# w
# a
# s
#
# a
#
# K
# F
# C
#
# o
# n
#
# t
# h
# e
#
# o
# t
# h
# e
# r
#
# s
# i
# d
# e
# !
#
#
#
#
# Q
# :
#
# W
# h
# y
#
# d
# i
# d
#
# t
# h
# e
#
# c
# h
# i
# c
# k
# e
# n
#
# c
# r
# o
# s
# s
#
# t
# h
# e
#
# r
# o
# a
# d
# ?
#
#
# A
# :
#
# T
# o
#
# s
# h
# o
# w
#
# e
# v
# e
# r
# y
# o
# n
# e
#
# h
# e
#
# w
# a
# s
# n
# '
# t
#
# c
# h
# i
# c
# k
# e
# n
# !
#
#
#
#
# Q
# :
#
# W
# h
# y
#
# d
# i
# d
#
# t
# h
# e
#
# l
# i
# o
# n
#
# s
# p
# i
# t
#
# o
# u
# t
#
# t
# h
# e
#
# c
# l
# o
# w
# n
# ?
#
#
# A
# :
#
# B
# e
# c
# a
# u
# s
# e
#
# h
# e
#
# t
# a
# s
# t
# e
# d
#
# f
# u
# n
# n
# y
# !
#
#
#
#
# Q
# :
#
# W
# h
# a
# t
#
# a
# n
# i
# m
# a
# l
# s
#
# a
# r
# e
#
# o
# n
#
# l
# e
# g
# a
# l
#
# d
# o
# c
# u
# m
# e
# n
# t
# s
# ?
#
#
# A
# :
#
# S
# e
# a
# l
# s
# !
#
#
#
#
# Q
# :
#
# W
# h
# a
# t
#
# d
# o
#
# y
# o
# u
#
# g
# e
# t
#
# w
# h
# e
# n
#
# y
# o
# u
#
# c
# r
# o
# s
# s
#
# a
#
# s
# n
# a
# k
# e
#
# a
# n
# d
#
# a
#
# p
# i
# e
# ?
#
#
# A
# :
#
# A
#
# p
# i
# e
# -
# t
# h
# o
# n
# !
#
#
#
#
# Q
# :
#
# W
# h
# a
# t
#
# d
# i
# d
#
# t
# h
# e
#
# b
# u
# f
# f
# a
# l
# o
#
# s
# a
# y
#
# t
# o
#
# h
# i
# s
#
# s
# o
# n
#
# w
# h
# e
# n
#
# h
# e
#
# w
# e
# n
# t
#
# a
# w
# a
# y
#
# o
# n
#
# a
#
# t
# r
# i
# p
# ?
#
#
# A
# :
#
# B
# i
# s
# o
# n
# !
#
#
#
#
# Q
# :
#
# H
# o
# w
#
# d
# o
#
# b
# e
# e
# s
#
# g
# e
# t
#
# t
# o
#
# s
# c
# h
# o
# o
# l
# ?
#
#
# A
# :
#
# B
# y
#
# s
# c
# h
# o
# o
# l
#
# b
# u
# z
# z
# !
#
#
#
#
# Q
# :
#
# W
# h
# a
# t
#
# d
# o
#
# y
# o
# u
#
# c
# a
# l
# l
#
# a
#
# b
# e
# a
# r
#
# w
# i
# t
# h
#
# n
# o
#
# e
# a
# r
# s
# ?
#
#
# A
# :
#
# B
# !
#
#
# A
# B
# C

# %%
with open('animal_jokes.txt', 'r') as f:
    for x in f.read(20):
        print(x)
# Out:
# Q
# :
#
# W
# h
# a
# t
#
# d
# o
#
# y
# o
# u
#
# c
# a
# l
# l

# %%
f = open('animal_jokes.txt', 'r')
for x in f.read():
    print(x)
# Out:
# Q
# :
#
# W
# h
# a
# t
#
# d
# o
#
# y
# o
# u
#
# c
# a
# l
# l
#
# a
#
# s
# l
# e
# e
# p
# i
# n
# g
#
# b
# u
# l
# l
# ?
#
#
# A
# :
#
# A
#
# b
# u
# l
# l
# -
# d
# o
# z
# e
# r
# .
#
#
#
#
# Q
# :
#
# H
# o
# w
#
# d
# o
# e
# s
#
# a
#
# l
# i
# o
# n
#
# g
# r
# e
# e
# t
#
# t
# h
# e
#
# o
# t
# h
# e
# r
#
# a
# n
# i
# m
# a
# l
# s
#
# i
# n
#
# t
# h
# e
#
# f
# i
# e
# l
# d
# ?
#
#
# A
# :
#
# P
# l
# e
# a
# s
# e
# d
#
# t
# o
#
# e
# a
# t
#
# y
# o
# u
# .
#
#
#
#
# Q
# :
#
# W
# h
# a
# t
#
# d
# i
# d
#
# t
# h
# e
#
# f
# a
# r
# m
# e
# r
#
# c
# a
# l
# l
#
# t
# h
# e
#
# c
# o
# w
#
# t
# h
# a
# t
#
# h
# a
# d
#
# n
# o
#
# m
# i
# l
# k
# ?
#
#
# A
# :
#
# A
# n
#
# u
# d
# d
# e
# r
#
# f
# a
# i
# l
# u
# r
# e
# .
#
#
#
#
# Q
# :
#
# W
# h
# y
#
# d
# o
#
# g
# o
# r
# i
# l
# l
# a
# s
#
# h
# a
# v
# e
#
# b
# i
# g
#
# n
# o
# s
# t
# r
# i
# l
# s
# ?
#
#
# A
# :
#
# B
# e
# c
# a
# u
# s
# e
#
# t
# h
# e
# y
#
# h
# a
# v
# e
#
# b
# i
# g
#
# f
# i
# n
# g
# e
# r
# s
# !
#
#
#
#
# Q
# :
#
# W
# h
# a
# t
#
# d
# o
#
# y
# o
# u
#
# g
# e
# t
#
# f
# r
# o
# m
#
# a
#
# p
# a
# m
# p
# e
# r
# e
# d
#
# c
# o
# w
# ?
#
#
# A
# :
#
# S
# p
# o
# i
# l
# e
# d
#
# m
# i
# l
# k
# .
#
#
#
#
# Q
# :
#
# W
# h
# y
#
# a
# r
# e
#
# t
# e
# d
# d
# y
#
# b
# e
# a
# r
# s
#
# n
# e
# v
# e
# r
#
# h
# u
# n
# g
# r
# y
# ?
#
#
# A
# :
#
# T
# h
# e
# y
#
# a
# r
# e
#
# a
# l
# w
# a
# y
# s
#
# s
# t
# u
# f
# f
# e
# d
# !
#
#
#
#
# Q
# :
#
# W
# h
# y
#
# d
# o
#
# f
# i
# s
# h
#
# l
# i
# v
# e
#
# i
# n
#
# s
# a
# l
# t
#
# w
# a
# t
# e
# r
# ?
#
#
# A
# :
#
# B
# e
# c
# a
# u
# s
# e
#
# p
# e
# p
# p
# e
# r
#
# m
# a
# k
# e
# s
#
# t
# h
# e
# m
#
# s
# n
# e
# e
# z
# e
# !
#
#
#
#
# Q
# :
#
# W
# h
# a
# t
#
# d
# o
#
# y
# o
# u
#
# g
# e
# t
#
# f
# r
# o
# m
#
# a
#
# p
# a
# m
# p
# e
# r
# e
# d
#
# c
# o
# w
# ?
#
#
# A
# :
#
# S
# p
# o
# i
# l
# e
# d
#
# m
# i
# l
# k
# .
#
#
#
#
# Q
# :
#
# W
# h
# e
# r
# e
#
# d
# o
#
# p
# o
# l
# a
# r
#
# b
# e
# a
# r
# s
#
# v
# o
# t
# e
# ?
#
#
# A
# :
#
# T
# h
# e
#
# N
# o
# r
# t
# h
#
# P
# o
# l
# l
#
#
#
#
# Q
# :
#
# W
# h
# y
#
# d
# i
# d
#
# t
# h
# e
#
# s
# n
# a
# k
# e
#
# c
# r
# o
# s
# s
#
# t
# h
# e
#
# r
# o
# a
# d
# ?
#
#
# A
# :
#
# T
# o
#
# g
# e
# t
#
# t
# o
#
# t
# h
# e
#
# o
# t
# h
# e
# r
#
# s
# s
# s
# s
# s
# s
# s
# i
# d
# e
# !
#
#
#
#
# Q
# :
#
# W
# h
# y
#
# a
# r
# e
#
# f
# i
# s
# h
#
# s
# o
#
# s
# m
# a
# r
# t
# ?
#
#
# A
# :
#
# B
# e
# c
# a
# u
# s
# e
#
# t
# h
# e
# y
#
# l
# i
# v
# e
#
# i
# n
#
# s
# c
# h
# o
# o
# l
# s
# .
#
#
#
#
# Q
# :
#
# W
# h
# a
# t
#
# f
# i
# s
# h
#
# o
# n
# l
# y
#
# s
# w
# i
# m
# s
#
# a
# t
#
# n
# i
# g
# h
# t
# ?
#
#
# A
# :
#
# A
#
# s
# t
# a
# r
# f
# i
# s
# h
# !
#
#
#
#
# Q
# :
#
# W
# h
# y
#
# i
# s
#
# a
#
# f
# i
# s
# h
#
# e
# a
# s
# y
#
# t
# o
#
# w
# e
# i
# g
# h
# ?
#
#
# A
# :
#
# B
# e
# c
# a
# u
# s
# e
#
# i
# t
#
# h
# a
# s
#
# i
# t
# s
#
# o
# w
# n
#
# s
# c
# a
# l
# e
# s
# !
#
#
#
#
# Q
# :
#
# W
# h
# a
# t
#
# d
# o
#
# y
# o
# u
#
# g
# e
# t
#
# w
# h
# e
# n
#
# a
#
# c
# h
# i
# c
# k
# e
# n
#
# l
# a
# y
# s
#
# a
# n
#
# e
# g
# g
#
# o
# n
#
# t
# o
# p
#
# o
# f
#
# a
#
# b
# a
# r
# n
# ?
#
#
# A
# :
#
# A
# n
#
# e
# g
# g
# r
# o
# l
# l
# !
#
#
#
#
# Q
# :
#
# W
# h
# y
#
# d
# i
# d
# n
# '
# t
#
# t
# h
# e
#
# c
# h
# i
# c
# k
# e
# n
#
# c
# r
# o
# s
# s
#
# t
# h
# e
#
# r
# o
# a
# d
# ?
#
#
# A
# :
#
# B
# e
# c
# a
# u
# s
# e
#
# t
# h
# e
# r
# e
#
# w
# a
# s
#
# a
#
# K
# F
# C
#
# o
# n
#
# t
# h
# e
#
# o
# t
# h
# e
# r
#
# s
# i
# d
# e
# !
#
#
#
#
# Q
# :
#
# W
# h
# y
#
# d
# i
# d
#
# t
# h
# e
#
# c
# h
# i
# c
# k
# e
# n
#
# c
# r
# o
# s
# s
#
# t
# h
# e
#
# r
# o
# a
# d
# ?
#
#
# A
# :
#
# T
# o
#
# s
# h
# o
# w
#
# e
# v
# e
# r
# y
# o
# n
# e
#
# h
# e
#
# w
# a
# s
# n
# '
# t
#
# c
# h
# i
# c
# k
# e
# n
# !
#
#
#
#
# Q
# :
#
# W
# h
# y
#
# d
# i
# d
#
# t
# h
# e
#
# l
# i
# o
# n
#
# s
# p
# i
# t
#
# o
# u
# t
#
# t
# h
# e
#
# c
# l
# o
# w
# n
# ?
#
#
# A
# :
#
# B
# e
# c
# a
# u
# s
# e
#
# h
# e
#
# t
# a
# s
# t
# e
# d
#
# f
# u
# n
# n
# y
# !
#
#
#
#
# Q
# :
#
# W
# h
# a
# t
#
# a
# n
# i
# m
# a
# l
# s
#
# a
# r
# e
#
# o
# n
#
# l
# e
# g
# a
# l
#
# d
# o
# c
# u
# m
# e
# n
# t
# s
# ?
#
#
# A
# :
#
# S
# e
# a
# l
# s
# !
#
#
#
#
# Q
# :
#
# W
# h
# a
# t
#
# d
# o
#
# y
# o
# u
#
# g
# e
# t
#
# w
# h
# e
# n
#
# y
# o
# u
#
# c
# r
# o
# s
# s
#
# a
#
# s
# n
# a
# k
# e
#
# a
# n
# d
#
# a
#
# p
# i
# e
# ?
#
#
# A
# :
#
# A
#
# p
# i
# e
# -
# t
# h
# o
# n
# !
#
#
#
#
# Q
# :
#
# W
# h
# a
# t
#
# d
# i
# d
#
# t
# h
# e
#
# b
# u
# f
# f
# a
# l
# o
#
# s
# a
# y
#
# t
# o
#
# h
# i
# s
#
# s
# o
# n
#
# w
# h
# e
# n
#
# h
# e
#
# w
# e
# n
# t
#
# a
# w
# a
# y
#
# o
# n
#
# a
#
# t
# r
# i
# p
# ?
#
#
# A
# :
#
# B
# i
# s
# o
# n
# !
#
#
#
#
# Q
# :
#
# H
# o
# w
#
# d
# o
#
# b
# e
# e
# s
#
# g
# e
# t
#
# t
# o
#
# s
# c
# h
# o
# o
# l
# ?
#
#
# A
# :
#
# B
# y
#
# s
# c
# h
# o
# o
# l
#
# b
# u
# z
# z
# !
#
#
#
#
# Q
# :
#
# W
# h
# a
# t
#
# d
# o
#
# y
# o
# u
#
# c
# a
# l
# l
#
# a
#
# b
# e
# a
# r
#
# w
# i
# t
# h
#
# n
# o
#
# e
# a
# r
# s
# ?
#
#
# A
# :
#
# B
# !
#
#
# A
# B
# C

# %%
for x in f.read():
    print(x)

# %%
# Note how the second for loop gives no output? That is because file objects themselves are iterators i.e. the iter() 
# function is called on creating the file object. And once exhausted cannot be used. 

f.close()

#Therefore, it is best to save the output of read, readlines etc to another variable, perform operations and then write back
# to file.

with open('animal_jokes.txt', 'r+') as f:
    data = f.readlines()
    data.insert(2, '\n Break From Animal Jokes\n')
    for x in data:
        print(x)
# Out:
# Q: What do you call a sleeping bull?
#
# A: A bull-dozer.
#
#
#  Break From Animal Jokes
#
#
#
#  Break From Animal Jokes
#
#
#
#  Break From Animal Jokes
#
#
#
#  Break From Animal Jokes
#
#
#
#  Break From Animal Jokes
#
#
#
# Q: How does a lion greet the other animals in the field?
#
# A: Pleased to eat you.
#
#
#
# Q: What did the farmer call the cow that had no milk?
#
# A: An udder failure.
#
#
#
# Q: Why do gorillas have big nostrils?
#
# A: Because they have big fingers!
#
#
#
# Q: What do you get from a pampered cow?
#
# A: Spoiled milk.
#
#
#
# Q: Why are teddy bears never hungry?
#
# A: They are always stuffed!
#
#
#
# Q: Why do fish live in salt water?
#
# A: Because pepper makes them sneeze!
#
#
#
# Q: What do you get from a pampered cow?
#
# A: Spoiled milk.
#
#
#
# Q: Where do polar bears vote?
#
# A: The North Poll
#
#
#
# Q: Why did the snake cross the road?
#
# A: To get to the other ssssssside!
#
#
#
# Q: Why are fish so smart?
#
# A: Because they live in schools.
#
#
#
# Q: What fish only swims at night?
#
# A: A starfish!
#
#
#
# Q: Why is a fish easy to weigh?
#
# A: Because it has its own scales!
#
#
#
# Q: What do you get when a chicken lays an egg on top of a barn?
#
# A: An eggroll!
#
#
#
# Q: Why didn't the chicken cross the road?
#
# A: Because there was a KFC on the other side!
#
#
#
# Q: Why did the chicken cross the road?
#
# A: To show everyone he wasn't chicken!
#
#
#
# Q: Why did the lion spit out the clown?
#
# A: Because he tasted funny!
#
#
#
# Q: What animals are on legal documents?
#
# A: Seals!
#
#
#
# Q: What do you get when you cross a snake and a pie?
#
# A: A pie-thon!
#
#
#
# Q: What did the buffalo say to his son when he went away on a trip?
#
# A: Bison!
#
#
#
# Q: How do bees get to school?
#
# A: By school buzz!
#
#
#
# Q: What do you call a bear with no ears?
#
# A: B!
#
# ABCQ: What do you call a sleeping bull?
#
# A: A bull-dozer.
#
#
#
# Break from animal jokes
#
#
#
#
#
# Break from animal jokes
#
#
#
#
#
# Break from animal jokes
#
#
#
#
#
# Q: How does a lion greet the other animals in the field?
#
# A: Pleased to eat you.
#
#
#
# Q: What did the farmer call the cow that had no milk?
#
# A: An udder failure.
#
#
#
# Q: Why do gorillas have big nostrils?
#
# A: Because they have big fingers!
#
#
#
# Q: What do you get from a pampered cow?
#
# A: Spoiled milk.
#
#
#
# Q: Why are teddy bears never hungry?
#
# A: They are always stuffed!
#
#
#
# Q: Why do fish live in salt water?
#
# A: Because pepper makes them sneeze!
#
#
#
# Q: What do you get from a pampered cow?
#
# A: Spoiled milk.
#
#
#
# Q: Where do polar bears vote?
#
# A: The North Poll
#
#
#
# Q: Why did the snake cross the road?
#
# A: To get to the other ssssssside!
#
#
#
# Q: Why are fish so smart?
#
# A: Because they live in schools.
#
#
#
# Q: What fish only swims at night?
#
# A: A starfish!
#
#
#
# Q: Why is a fish easy to weigh?
#
# A: Because it has its own scales!
#
#
#
# Q: What do you get when a chicken lays an egg on top of a barn?
#
# A: An eggroll!
#
#
#
# Q: Why didn't the chicken cross the road?
#
# A: Because there was a KFC on the other side!
#
#
#
# Q: Why did the chicken cross the road?
#
# A: To show everyone he wasn't chicken!
#
#
#
# Q: Why did the lion spit out the clown?
#
# A: Because he tasted funny!
#
#
#
# Q: What animals are on legal documents?
#
# A: Seals!
#
#
#
# Q: What do you get when you cross a snake and a pie?
#
# A: A pie-thon!
#
#
#
# Q: What did the buffalo say to his son when he went away on a trip?
#
# A: Bison!
#
#
#
# Q: How do bees get to school?
#
# A: By school buzz!
#
#
#
# Q: What do you call a bear with no ears?
#
# A: B!
#
# ABC

# %%
with open('animal_jokes.txt', 'r+') as f:
    f.write('\nI hope you like animal jokes\n\n')

#Note how - since we did not do any read operations, cursor is at beginning of file and overwrote the portion of file till
# the inserted string.

# %%
with open('animal_jokes.txt', 'r+') as f:
    f.seek(100)
    f.write('\nBreak from animal jokes \n\n')

# Inserted the specified string at specified index position.

# %%
with open('animal_jokes.txt', 'r') as f:
    print(len(f.read()))
# Out:
# 3095

# %%
with open('animal_jokes.txt', 'r') as f:
    print(len(f.readlines()))
# Out:
# 148

# %%
# readline method for file objects - reads until the newline character is reached. On next readline call - it will read
# from where the handle/cursor stopped at last iteration.

# %%
with open('animal_jokes.txt', 'r') as f:
    for x in f.readline():
        print(x)
# Out:
# Q
# :
#
# W
# h
# a
# t
#
# d
# o
#
# y
# o
# u
#
# c
# a
# l
# l
#
# a
#
# s
# l
# e
# e
# p
# i
# n
# g
#
# b
# u
# l
# l
# ?

# %%
f = open('animal_jokes.txt', 'r')
print(f.readline())
# Out:
# ï»¿Q: What do you call a sleeping bull?

# %%
print(f.readline())
# Out:
# A: A bull-dozer.

# %%
print(f.readline())
# Out:
# Q: How does a lion greet the other animals in the field?

# %%
print(f.readline())
# Out:
# A: Pleased to eat you.

# %%
f.close()

# %%
#Readlines method returns all the lines in the document in the form of a list. 
with open('animal_jokes.txt', 'r') as f:
    print(f.readlines())
# Out:
# ['Q: What do you call a sleeping bull?\n', 'A: A bull-dozer.\n', '\n', 'Q: How does a lion greet the other animals in the field?\n', 'A: Pleased to eat you.\n', '\n', 'Q: What did the farmer call the cow that had no milk?\n', 'A: An udder failure.\n', '\n', 'Q: Why do gorillas have big nostrils?\n', 'A: Because they have big fingers!\n', '\n', 'Q: What do you get from a pampered cow?\n', 'A: Spoiled milk.\n', '\n', 'Q: Why are teddy bears never hungry?\n', 'A: They are always stuffed!\n', '\n', 'Q: Why do fish live in salt water?\n', 'A: Because pepper makes them sneeze!\n', '\n', 'Q: What do you get from a pampered cow?\n', 'A: Spoiled milk.\n', '\n', 'Q: Where do polar bears vote?\n', 'A: The North Poll\n', '\n', 'Q: Why did the snake cross the road?\n', 'A: To get to the other ssssssside!\n', '\n', 'Q: Why are fish so smart?\n', 'A: Because they live in schools.\n', '\n', 'Q: What fish only swims at night?\n', 'A: A starfish!\n', '\n', 'Q: Why is a fish easy to weigh?\n', 'A: Because it has its own scales!\n', '\n', 'Q: What do you get when a chicken lays an egg on top of a barn?\n', 'A: An eggroll!\n', '\n', "Q: Why didn't the chicken cross the road?\n", 'A: Because there was a KFC on the other side!\n', '\n', 'Q: Why did the chicken cross the road?\n', "A: To show everyone he wasn't chicken!\n", '\n', 'Q: Why did the lion spit out the clown?\n', 'A: Because he tasted funny!\n', '\n', 'Q: What animals are on legal documents?\n', 'A: Seals!\n', '\n', 'Q: What do you get when you cross a snake and a pie?\n', 'A: A pie-thon!\n', '\n', 'Q: What did the buffalo say to his son when he went away on a trip?\n', 'A: Bison!\n', '\n', 'Q: How do bees get to school?\n', 'A: By school buzz!\n', '\n', 'Q: What do you call a bear with no ears?\n', 'A: B!']

# %%
f = open('animal_jokes.txt', 'r+')
data = f.read()
print(data)
# Out:
# No more animal jokes
#
# ping bull?
# A: A bull-dozer.
#
# Q: How does a lion greet the other animals in the field?
# A: Pleased to eat you.
#
# Q: What did the farmer call the cow that had no milk?
# A: An udder failure.
#
# Q: Why do gorillas have big nostrils?
# A: Because they have big fingers!
#
# Q: What do you get from a pampered cow?
# A: Spoiled milk.
#
# Q: Why are teddy bears never hungry?
# A: They are always stuffed!
#
# Q: Why do fish live in salt water?
# A: Because pepper makes them sneeze!
#
# Q: What do you get from a pampered cow?
# A: Spoiled milk.
#
# Q: Where do polar bears vote?
# A: The North Poll
#
# Q: Why did the snake cross the road?
# A: To get to the other ssssssside!
#
# Q: Why are fish so smart?
# A: Because they live in schools.
#
# Q: What fish only swims at night?
# A: A starfish!
#
# Q: Why is a fish easy to weigh?
# A: Because it has its own scales!
#
# Q: What do you get when a chicken lays an egg on top of a barn?
# A: An eggroll!
#
# Q: Why didn't the chicken cross the roa

# %%
#If you notice, in the list of lines from the readlines method, each line ends with a newline character - '\n'. To suppress
# this we could use the splitlines method.

with open('animal_jokes.txt', 'r+') as f:
    data = f.read().splitlines()
    print(data)
# Out:
# ['', 'No more animal jokes', '', 'ping bull?', 'A: A bull-dozer.', '', 'Q: How does a lion greet the other animals in the field?', 'A: Pleased to eat you.', '', 'Q: What did the farmer call the cow that had no milk?', 'A: An udder failure.', '', 'Q: Why do gorillas have big nostrils?', 'A: Because they have big fingers!', '', 'Q: What do you get from a pampered cow?', 'A: Spoiled milk.', '', 'Q: Why are teddy bears never hungry?', 'A: They are always stuffed!', '', 'Q: Why do fish live in salt water?', 'A: Because pepper makes them sneeze!', '', 'Q: What do you get from a pampered cow?', 'A: Spoiled milk.', '', 'Q: Where do polar bears vote?', 'A: The North Poll', '', 'Q: Why did the snake cross the road?', 'A: To get to the other ssssssside!', '', 'Q: Why are fish so smart?', 'A: Because they live in schools.', '', 'Q: What fish only swims at night?', 'A: A starfish!', '', 'Q: Why is a fish easy to weigh?', 'A: Because it has its own scales!', '', 'Q: What do you get when a chicken lays an egg on top of a barn?', 'A: An eggroll!', '', "Q: Why didn't the chicken cross the roa"]

# %%
for x in data:
    print(x)
# Out:
# Q: What do you call a sleeping bull?
# A: A bull-dozer.
#
# Q: How does a lion greet the other animals in the field?
# A: Pleased to eat you.
#
# Q: What did the farmer call the cow that had no milk?
# A: An udder failure.
#
# Q: Why do gorillas have big nostrils?
# A: Because they have big fingers!
#
# Q: What do you get from a pampered cow?
# A: Spoiled milk.
#
# Q: Why are teddy bears never hungry?
# A: They are always stuffed!
#
# Q: Why do fish live in salt water?
# A: Because pepper makes them sneeze!
#
# Q: What do you get from a pampered cow?
# A: Spoiled milk.
#
# Q: Where do polar bears vote?
# A: The North Poll
#
# Q: Why did the snake cross the road?
# A: To get to the other ssssssside!
#
# Q: Why are fish so smart?
# A: Because they live in schools.
#
# Q: What fish only swims at night?
# A: A starfish!
#
# Q: Why is a fish easy to weigh?
# A: Because it has its own scales!
#
# Q: What do you get when a chicken lays an egg on top of a barn?
# A: An eggroll!
#
# Q: Why didn't the chicken cross the road?
# A: Because there was a KFC on the other side!
#
# Q: Why did the chicken cross the road?
# A: To show everyone he wasn't chicken!
#
# Q: Why did the lion spit out the clown?
# A: Because he tasted funny!
#
# Q: What animals are on legal documents?
# A: Seals!
#
# Q: What do you get when you cross a snake and a pie?
# A: A pie-thon!
#
# Q: What did the buffalo say to his son when he went away on a trip?
# A: Bison!
#
# Q: How do bees get to school?
# A: By school buzz!
#
# Q: What do you call a bear with no ears?
# A: B!

# %%
#Please remember that splitlines is a string method and not a file object method.

# %%
#Also, the use of readlines method since Python 2.3 has been somewhat deprecated. We can get the same result with : 
f = open('animal_jokes.txt', 'a+')
f.seek(0)
print(len(f.readlines()))
# Out:
# 65

# %%
# If you remember the example from input cell 62 above which was as follows to re-write contents to another file:

# %%
# # Re-writing the text to the animals_jokes file using multiple with open

with open('animal_jokes.txt', 'w+') as aj, open('animal_jokes_Copy.txt', 'r') as ajCopy:
    data = ajCopy.readlines()
    aj.writelines(data)

# We used the above.

# %%
# Clearing contents of animal_jokes.txt and only inputting XYZ.

with open('animal_jokes.txt', 'w') as f:
    f.write('xyz')

# %%
# Rewriting contents of animal_jokes_copy.txt to animal_jokes.txt with cleaner syntax.

with open('animal_jokes.txt', 'w+') as aj, open('animal_jokes_Copy.txt', 'r') as ajCopy:
    data = ajCopy.readlines()
    aj.writelines(ajCopy)
#     data = ajCopy.readlines()
    for x in data:
        print(x)
# Out:
# Q: What do you call a sleeping bull?
#
# A: A bull-dozer.
#
#
#
# Q: How does a lion greet the other animals in the field?
#
# A: Pleased to eat you.
#
#
#
# Q: What did the farmer call the cow that had no milk?
#
# A: An udder failure.
#
#
#
# Q: Why do gorillas have big nostrils?
#
# A: Because they have big fingers!
#
#
#
# Q: What do you get from a pampered cow?
#
# A: Spoiled milk.
#
#
#
# Q: Why are teddy bears never hungry?
#
# A: They are always stuffed!
#
#
#
# Q: Why do fish live in salt water?
#
# A: Because pepper makes them sneeze!
#
#
#
# Q: What do you get from a pampered cow?
#
# A: Spoiled milk.
#
#
#
# Q: Where do polar bears vote?
#
# A: The North Poll
#
#
#
# Q: Why did the snake cross the road?
#
# A: To get to the other ssssssside!
#
#
#
# Q: Why are fish so smart?
#
# A: Because they live in schools.
#
#
#
# Q: What fish only swims at night?
#
# A: A starfish!
#
#
#
# Q: Why is a fish easy to weigh?
#
# A: Because it has its own scales!
#
#
#
# Q: What do you get when a chicken lays an egg on top of a barn?
#
# A: An eggroll!
#
#
#
# Q: Why didn't the chicken cross the road?
#
# A: Because there was a KFC on the other side!
#
#
#
# Q: Why did the chicken cross the road?
#
# A: To show everyone he wasn't chicken!
#
#
#
# Q: Why did the lion spit out the clown?
#
# A: Because he tasted funny!
#
#
#
# Q: What animals are on legal documents?
#
# A: Seals!
#
#
#
# Q: What do you get when you cross a snake and a pie?
#
# A: A pie-thon!
#
#
#
# Q: What did the buffalo say to his son when he went away on a trip?
#
# A: Bison!
#
#
#
# Q: How do bees get to school?
#
# A: By school buzz!
#
#
#
# Q: What do you call a bear with no ears?
#
# A: B!

# %%
# readable() method returns whether the file object has reading permissions (True) or not (False).

with open('animal_jokes.txt', 'w+') as f:
    print(f.readable())
# Out:
# True

# %%
with open('animal_jokes.txt', 'w') as f:
    print(f.readable())
# Out:
# False

# %%
# write method - writes the specified string to the file object.

with open('animal_jokes.txt', 'a') as f:
    f.write('\nNo more animal jokes')

# %%
with open('animal_jokes.txt', 'r') as f:
    f.seek(1400)
    for x in f.readlines():
        print(x)
# Out:
# A: Bison!
#
#
#
# Q: How do bees get to school?
#
# A: By school buzz!
#
#
#
# Q: What do you call a bear with no ears?
#
# A: B!

# %%
with open('animal_jokes.txt', 'w+') as f:
    f.write('1st string', '2nd string')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-1effde1ed8b9> in <module>
#       1 with open('animal_jokes.txt', 'w+') as f:
# ----> 2     f.write('1st string', '2nd string')
#
# TypeError: write() takes exactly one argument (2 given)

# %%
# Note the error when trying to write more than one string.

# %%
x = '\nJokes keep the mood light hearted.\n\n'

with open('animal_jokes.txt', 'a+') as f:
    f.write(x)

# %%
#writelines method

# %%
add_jokes = ['Q: What do you get when you cross a snake and a pie?\n', 'A: A pie-thon!\n','Q: What did the buffalo say to\
his son when he went away on a trip?\n','A: Bison!\n','Q: How do bees get to school?\n','A: By school buzz!\n','Q: What do\
you call a bear with no ears?\n','A: B!\n']

with open('animal_jokes.txt', 'a+') as f:
    f.writelines(add_jokes)

# %%
with open('animal_jokes.txt', 'w') as f:
    f.write('XY')

# %%
add_jokes_tup = tuple(add_jokes)
print(add_jokes_tup)
# Out:
# ('Q: What do you get when you cross a snake and a pie?\n', 'A: A pie-thon!\n', 'Q: What did the buffalo say tohis son when he went away on a trip?\n', 'A: Bison!\n', 'Q: How do bees get to school?\n', 'A: By school buzz!\n', 'Q: What doyou call a bear with no ears?\n', 'A: B!\n')

# %%
# Writelines can take any iterable. 

with open('animal_jokes.txt', 'w+') as f:
    f.writelines(add_jokes_tup)

# %%
    
with open('animal_jokes.txt', 'r') as f:
    for x in f:
        print(x)
# Out:
# Q: What do you get when you cross a snake and a pie?
#
# A: A pie-thon!
#
# Q: What did the buffalo say tohis son when he went away on a trip?
#
# A: Bison!
#
# Q: How do bees get to school?
#
# A: By school buzz!
#
# Q: What doyou call a bear with no ears?
#
# A: B!

# %%
with open('animal_jokes.txt', 'w+') as aj, open('animal_jokes_copy.txt', 'r') as ajCopy:
    aj.writelines(ajCopy)
    aj.flush()
    aj.seek(0)
    data = aj.readlines()
    for x in data:
        print(x)


# with open('animal_jokes.txt', 'w+') as aj, open('animal_jokes_Copy.txt', 'r') as ajCopy:
#     data = ajCopy.readlines()
#     aj.writelines(data)
#     for x in data:
#         print(x)
# Out:
# Q: What do you call a sleeping bull?
#
# A: A bull-dozer.
#
#
#
# Q: How does a lion greet the other animals in the field?
#
# A: Pleased to eat you.
#
#
#
# Q: What did the farmer call the cow that had no milk?
#
# A: An udder failure.
#
#
#
# Q: Why do gorillas have big nostrils?
#
# A: Because they have big fingers!
#
#
#
# Q: What do you get from a pampered cow?
#
# A: Spoiled milk.
#
#
#
# Q: Why are teddy bears never hungry?
#
# A: They are always stuffed!
#
#
#
# Q: Why do fish live in salt water?
#
# A: Because pepper makes them sneeze!
#
#
#
# Q: What do you get from a pampered cow?
#
# A: Spoiled milk.
#
#
#
# Q: Where do polar bears vote?
#
# A: The North Poll
#
#
#
# Q: Why did the snake cross the road?
#
# A: To get to the other ssssssside!
#
#
#
# Q: Why are fish so smart?
#
# A: Because they live in schools.
#
#
#
# Q: What fish only swims at night?
#
# A: A starfish!
#
#
#
# Q: Why is a fish easy to weigh?
#
# A: Because it has its own scales!
#
#
#
# Q: What do you get when a chicken lays an egg on top of a barn?
#
# A: An eggroll!
#
#
#
# Q: Why didn't the chicken cross the road?
#
# A: Because there was a KFC on the other side!
#
#
#
# Q: Why did the chicken cross the road?
#
# A: To show everyone he wasn't chicken!
#
#
#
# Q: Why did the lion spit out the clown?
#
# A: Because he tasted funny!
#
#
#
# Q: What animals are on legal documents?
#
# A: Seals!
#
#
#
# Q: What do you get when you cross a snake and a pie?
#
# A: A pie-thon!
#
#
#
# Q: What did the buffalo say to his son when he went away on a trip?
#
# A: Bison!
#
#
#
# Q: How do bees get to school?
#
# A: By school buzz!
#
#
#
# Q: What do you call a bear with no ears?
#
# A: B!

# %%
# writable method returns True if file object is able to be written into, False if not.

# %%
with open('animal_jokes.txt', 'r+') as f:
    print(f.writable())
# Out:
# True

# %%
with open('animal_jokes.txt', 'r') as f:
    print(f.writable())
# Out:
# False

# %%
# seek method sends the cursor/handle to the specified index number.
# tell method tells you the cursor position

# %%
with open('animal_jokes.txt', 'r') as f:
    print(f.tell())
    f.seek(100)
    print(f.tell())
# Out:
# 0
# 100

# %%
# Until Python 3.2, we could use a second parameter - 
# 1 for seek relative to current position i.e. if cursor is at 100 and we specified f.seek(100,1) cursor would go to 200.
# 2 for seek relative to end of file i.e. if cursor was at end of file, then f.seek(-100,2) would take cursor 100 steps
# back. However, these have been deprecated from Python 3.2 and now the only relative seek that works is complete end of
# file i.e.

with open('animal_jokes.txt', 'r') as f:
    f.seek(0,2)
    print(f.tell())
# Out:
# 1515

# %%
with open('animal_jokes.txt', 'r') as f:
    print(len(f.read()))
# Out:
# 1451

# %%
with open('animal_jokes.txt', 'r') as f:
    print(len(f.readlines()))
# Out:
# 65

# %%
# As noticed, in the read, newline characters are already parsed and not counted. However, as you can see in the readlines
# there are 44 lines, so read characters (1432) + lines (44) is adding up to the cursor being at the end index i.e. 1476

# %%
# seekable - Returns True if the file allows us to change the cursor/handle/file position else False.

with open('animal_jokes.txt', 'r') as f:
    print(f.seekable())

# Assumption is that when working with very large file sizes overflowing the buffer, the seekable() function 
# may return False. Not sure of the use since have not come across a use case for this.
# Out:
# True

# %%
# truncate() resizes the file to the specified size.

with open('animal_jokes.txt', 'r') as f:
    f.seek(1000)
    for x in f:
        print(x)
# Out:
# d?
#
# A: Because there was a KFC on the other side!
#
#
#
# Q: Why did the chicken cross the road?
#
# A: To show everyone he wasn't chicken!
#
#
#
# Q: Why did the lion spit out the clown?
#
# A: Because he tasted funny!
#
#
#
# Q: What animals are on legal documents?
#
# A: Seals!
#
#
#
# Q: What do you get when you cross a snake and a pie?
#
# A: A pie-thon!
#
#
#
# Q: What did the buffalo say to his son when he went away on a trip?
#
# A: Bison!
#
#
#
# Q: How do bees get to school?
#
# A: By school buzz!
#
#
#
# Q: What do you call a bear with no ears?
#
# A: B!

# %%
with open('animal_jokes.txt', 'r+') as f:
    f.truncate(1000)
    f.seek(0)
    for x in f:
        print(x)
# Out:
# Q: What do you call a sleeping bull?
#
# A: A bull-dozer.
#
#
#
# Q: How does a lion greet the other animals in the field?
#
# A: Pleased to eat you.
#
#
#
# Q: What did the farmer call the cow that had no milk?
#
# A: An udder failure.
#
#
#
# Q: Why do gorillas have big nostrils?
#
# A: Because they have big fingers!
#
#
#
# Q: What do you get from a pampered cow?
#
# A: Spoiled milk.
#
#
#
# Q: Why are teddy bears never hungry?
#
# A: They are always stuffed!
#
#
#
# Q: Why do fish live in salt water?
#
# A: Because pepper makes them sneeze!
#
#
#
# Q: What do you get from a pampered cow?
#
# A: Spoiled milk.
#
#
#
# Q: Where do polar bears vote?
#
# A: The North Poll
#
#
#
# Q: Why did the snake cross the road?
#
# A: To get to the other ssssssside!
#
#
#
# Q: Why are fish so smart?
#
# A: Because they live in schools.
#
#
#
# Q: What fish only swims at night?
#
# A: A starfish!
#
#
#
# Q: Why is a fish easy to weigh?
#
# A: Because it has its own scales!
#
#
#
# Q: What do you get when a chicken lays an egg on top of a barn?
#
# A: An eggroll!
#
#
#
# Q: Why didn't the chicken cross the roa

# %%
#flush method - flushes the internal buffer and writes to file (or if no write call given, disposes the data)

# If you recall, we had an example above where we did a write procedure but the result was not displayed till we closed, 
# the file object and then displayed in the next file object creation call with open.

# %%
with open('animal_jokes.txt', 'r+') as f:
    f.write('\nNo more animal jokes\n\n')
    f.flush()
    f.seek(0)
    for x in f.readlines(100):
        print(x)
# Out:
# No more animal jokes
#
#
#
# ping bull?
#
# A: A bull-dozer.
#
#
#
# Q: How does a lion greet the other animals in the field?

# %%
# fileno() Returns a number that represents the stream. 

with open('animal_jokes.txt', 'r') as f:
    print(f.fileno())
# Out:
# 4

# %%
# detach method used to detach input rawstream from file buffer. 

f = open('animal_jokes.txt', 'r')
f.detach()
for x in f.readlines():
    print(x)
f.close()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [101], in <cell line: 5>()
#       3 f = open('animal_jokes.txt', 'r')
#       4 f.detach()
# ----> 5 for x in f.readlines():
#       6     print(x)
#       7 f.close()
#
# ValueError: underlying buffer has been detached

# %%
# Attributes. 

# We have already seen the closed attribute. 

f = open('animal_jokes.txt', 'r')
print(f.closed)
f.close()
print(f.closed)

# %%
# encoding - displays the encoding used on the file.

f = open('animal_jokes.txt', 'r')
print(f.encoding)
# Out:
# cp1252

# %%
# If you recall, when discussing encoding in Bytes and Bytearrays - we had discussed that - by default Python uses UTF-8
# encoding BUT open function will be system dependent. Windows uses cp1252 and therefore the encoding on this file is 
# cp1252. Your outputs may be different depending on your systems.

# %%
# mode - displays the mode of the file object i.e. the permissions. 

print(f.mode)
# Out:
# r

# %%
# name displays the file name if the file has been opened as a file object. 

print(f.name)
# Out:
# animal_jokes.txt

# %%
f.close()

# %%
with open('animal_jokes.txt', 'r') as f:
    f.seek(630)
    for x in f:
        print(x)
# Out:
# e road?
#
# A: To get to the other ssssssside!
#
# Q: Why are fish so smart?
#
# A: Because they live in schools.
#
# Q: What fish only swims at night?
#
# A: A starfish!
#
# Q: Why is a fish easy to weigh?
#
# A: Because it has its own scales!
#
# Q: What do you get when a chicken lays an egg on top of a barn?
#
# A: An eggroll!
#
# Q: Why didn't the chicken cross the road?
#
# A: Because there was

# %%
#Binary files

# %%
# The modes to open binary files are the same as text file, only add b before the mode to specify opening in binary format.

# %%
from IPython import display
display.Image('watermelon32x32.jpg')

# %%
with open('watermelon32x32.jpg', 'rb') as imgf:
    for x in imgf:
        print(len(x))
        print(x, '\n', '-'*100)
# Out:
# 66
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00`\x00`\x00\x00\xff\xdb\x00C\x00\x02\x01\x01\x02\x01\x01\x02\x02\x02\x02\x02\x02\x02\x02\x03\x05\x03\x03\x03\x03\x03\x06\x04\x04\x03\x05\x07\x06\x07\x07\x07\x06\x07\x07\x08\t\x0b\t\x08\x08\n'
#  ----------------------------------------------------------------------------------------------------
# 4
# b'\x08\x07\x07\n'
#  ----------------------------------------------------------------------------------------------------
# 2
# b'\r\n'
#  ----------------------------------------------------------------------------------------------------
# 1
# b'\n'
#  ----------------------------------------------------------------------------------------------------
# 136
# b'\x0b\x0c\x0c\x0c\x0c\x07\t\x0e\x0f\r\x0c\x0e\x0b\x0c\x0c\x0c\xff\xdb\x00C"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n'
#  ----------------------------------------------------------------------------------------------------
# 61
# b'\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n'
#  ----------------------------------------------------------------------------------------------------
# 155
# b"\x16\x17\x18\x19\x1a%&'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\t\n"
#  ----------------------------------------------------------------------------------------------------
# 59
# b'\x0b\xff\xc4\x00\xb5\x11\x00\x02\x01\x02\x04\x04\x03\x04\x07\x05\x04\x04\x00\x01\x02w\x00\x01\x02\x03\x11\x04\x05!1\x06\x12AQ\x07aq\x13"2\x81\x08\x14B\x91\xa1\xb1\xc1\t#3R\xf0\x15br\xd1\n'
#  ----------------------------------------------------------------------------------------------------
# 698
# b"\x16$4\xe1%\xf1\x17\x18\x19\x1a&'()*56789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz?\x00\xfd\xfc\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8c\xe2\x8c\xd0\x01E\x14P\x01E\x19\xc5&h\x01h\xa2\x8a\x00(\xa2\x934\x00\xb4QE\x00\x14QE\x00\x14QE\x00\x14QE\x00\x14QE\x00\x14QE\x00\x14QE\x00\x14QE\x00\x14QE\x00\x14QE\x00E\xd6\x94\x9cW\x15\xf1C\xe3_\x87\xbe\x0b\xe9\x1fl\xd7\xaf\x16\xd3<[@\x0ef\xba?\xecG_7\xeb?\xb6\x1f\x8a~5\xb1\xb5\xf0\x9e\x93{g\xa4\x13\xf6cs\xfe\xa0\x7f\xe0G\xff\x00\x1b\xac+W\xa5K\xf8\xa7%\\]*z\x1fS\xeb~6\xd2|)\xff\x00!=N\xce\xccc?\xbf\xb9\xfd\xe9\xff\x00\xb6u\xc5\xea\xdf\xb5\x1f\x85\xb4\xa4\xc5\xa9\xd5\xef\xff\x00\xeb\x85\xac\x9f\xfb=|C\xf1\xc3\xf6\x80\xd0?f]*\xf2\xeb\xc6\xfe,\xb3\xfe\xd8\xbc\xff\x00J\xfe\xce\xd3\x7f}}u\xff\x00m\x1f\xf7\x9e_\xfd4\xff\x00W^A\xe0\x0f\xda\xc3_\xf8\xdd\xff\x00\x13m'\xc3\xd6~\x1a\xf0\xdf\xfd\x06\xb5\xab\x99\x7f\xd2\xbf\xeb\x9ci\xe5\xef\xff\x00\xae\x9eg\x97\\us\xdc\xbe\x97\xf1j\x1cUs?\xf9v\x8f\xd0\xcf\
ed~\x13\xf1\r\xe7\x86\xae\xff\x00\xea\x1d\xa9y?j\xff\x00\xae\x9f\xdf\xaf\xd2j1\x9a\xc6\xae[J\xa0\x1f\x1fxs\xe0\x87\xc6\x8f\t\xe9\x7fd\xbb\xbb\xb3\xf1-\xa7\xfd<\xf9P\xcf\xff\x00\x7f\x12\xba\x8b\x1d\x03\xe2O\xfc\xbd\xf8\x7f\xff\x00\x01\xb58\xa6\xff\x00\xd0\xe3\xaf\xa5i1^u\\\x8b\x0ce\xec\x99\xf3-\xf5\x87\xc4\x9c\xff\x00\xc8\xbfw\xf6O\xfbe\xff\x00\xc7*\xac\xf0|S\xff\x00\x97O\n'
#  ----------------------------------------------------------------------------------------------------
# 87
# b'j\xff\x00\xf6\xf3um_Rm\x14m\x15\xcf\xfe\xab\xe1\xff\x00\xe7\xe4\xc7\xec\x8f\x8d<I\xa3\xfc~\xd5\xbf\xe4\x13\xe1=\x1e\xcf\xfe\xbeu?;\xff\x00i\xc7\\\x86\xbd\xfb=~\xd4\xde?\\\x9f\x11xo\xc3#\xb9\xd3\xad\xbf|?\xef\xff\x00\x99\xff\x00\x90\xeb\xef\x93\x8a\x00\x19\xae\x8f\xf5w\n'
#  ----------------------------------------------------------------------------------------------------
# 171
# b"/eL\xfc\xd5\xb0\xff\x00\x82I|H\xd5\xb5\x7f\xedO\x10x\xe2\xee\xf6\xf7\xaf\xda.n\xa4\x9a\xbd\x7f\xe1\xff\x00\xfc\x13\x83_\xf0\xa8\xff\x00J\xf1\x0e~\x95\xf6\x8e1Ez4r\xdaT\xb65<_\xc0\xdf\xb3M\xcf\x85G\xfaV\xad^\x95\xa5\xf8K\xfb'\xfe^MmQ]\x94\xa8\xd3\xa7\xb0\x04P\xed\x15%\x14V\xc0\x14QE\x00\x14QE\x00\x14QE\x00\x14QE\x00\x14QE\x00\x14QE\x00\x14QE\x00\x14QE\x00\x14QE\x00\x14QE\x00\x14QE\x00\x14QE\x00\x18\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x03\xff\xd9"
#  ----------------------------------------------------------------------------------------------------

# %%
with open('watermelon32x32.jpg', 'rb+') as img_f:
    data = img_f.readlines()
    for x in range(len(data)):
        print(f'Line no. {x}, length : {len(data[x])} and type : {type(data[x])}.')
        print('-'*125)
        print(f'Data : {data[x]}.')
# Out:
# Line no. 0, length : 66 and type : <class 'bytes'>.
# -----------------------------------------------------------------------------------------------------------------------------
# Data : b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00`\x00`\x00\x00\xff\xdb\x00C\x00\x02\x01\x01\x02\x01\x01\x02\x02\x02\x02\x02\x02\x02\x02\x03\x05\x03\x03\x03\x03\x03\x06\x04\x04\x03\x05\x07\x06\x07\x07\x07\x06\x07\x07\x08\t\x0b\t\x08\x08\n'.
# Line no. 1, length : 4 and type : <class 'bytes'>.
# -----------------------------------------------------------------------------------------------------------------------------
# Data : b'\x08\x07\x07\n'.
# Line no. 2, length : 2 and type : <class 'bytes'>.
# -----------------------------------------------------------------------------------------------------------------------------
# Data : b'\r\n'.
# Line no. 3, length : 1 and type : <class 'bytes'>.
# -----------------------------------------------------------------------------------------------------------------------------
# Data : b'\n'.
# Line no. 4, length : 136 and type : <class 'bytes'>.
# -----------------------------------------------------------------------------------------------------------------------------
# Data : b'\x0b\x0c\x0c\x0c\x0c\x07\t\x0e\x0f\r\x0c\x0e\x0b\x0c\x0c\x0c\xff\xdb\x00C"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n'.
# Line no. 5, length : 61 and type : <class 'bytes'>.
# -----------------------------------------------------------------------------------------------------------------------------
# Data : b'\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n'.
# Line no. 6, length : 155 and type : <class 'bytes'>.
# -----------------------------------------------------------------------------------------------------------------------------
# Data : b"\x16\x17\x18\x19\x1a%&'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\t\n".
# Line no. 7, length : 59 and type : <class 'bytes'>.
# -----------------------------------------------------------------------------------------------------------------------------
# Data : b'\x0b\xff\xc4\x00\xb5\x11\x00\x02\x01\x02\x04\x04\x03\x04\x07\x05\x04\x04\x00\x01\x02w\x00\x01\x02\x03\x11\x04\x05!1\x06\x12AQ\x07aq\x13"2\x81\x08\x14B\x91\xa1\xb1\xc1\t#3R\xf0\x15br\xd1\n'.
# Line no. 8, length : 698 and type : <class 'bytes'>.
# -----------------------------------------------------------------------------------------------------------------------------
# Data : b"\x16$4\xe1%\xf1\x17\x18\x19\x1a&'()*56789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz?\x00\xfd\xfc\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8c\xe2\x8c\xd0\x01E\x14P\x01E\x19\xc5&h\x01h\xa2\x8a\x00(\xa2\x934\x00\xb4QE\x00\x14QE\x00\x14QE\x00\x14QE\x00\x14QE\x00\x14QE\x00\x14QE\x00\x14QE\x00\x14QE\x00\x14QE\x
and type : <class 'bytes'>.
# -----------------------------------------------------------------------------------------------------------------------------
# Data : b'\xfcR2|=i\xf8W\t\xe2O\xf8$\x07\xc2\x1f\x15\x8f\xf9\x04\xd7\xd6tV_T\xa4\x07\xc3Z\xef\xfc\x10\xc7\xe1^\xa6?\xd1mq\xf5\xae_T\xff\x00\x82\x0cx,\xff\x00\xc7\xa7\xd9+\xf46\x8a>\xa9H\x0f\xcc\xfb\xff\x00\xf8 \x8e\x94\xbf\xf1\xeal\xea\xd7\x81\xff\x00\xe0\x8e\x1a\xf7\xc2mS\xed~\x13\xf1\r\xe7\x86\xae\xff\x00\xea\x1d\xa9y?j\xff\x00\xae\x9f\xdf\xaf\xd2j1\x9a\xc6\xae[J\xa0\x1f\x1fxs\xe0\x87\xc6\x8f\t\xe9\x7fd\xbb\xbb\xb3\xf1-\xa7\xfd<\xf9P\xcf\xff\x00\x7f\x12\xba\x8b\x1d\x03\xe2O\xfc\xbd\xf8\x7f\xff\x00\x01\xb58\xa6\xff\x00\xd0\xe3\xaf\xa5i1^u\\\x8b\x0ce\xec\x99\xf3-\xf5\x87\xc4\x9c\xff\x00\xc8\xbfw\xf6O\xfbe\xff\x00\xc7*\xac\xf0|S\xff\x00\x97O\n'.
# Line no. 42, length : 87 and type : <class 'bytes'>.
# -----------------------------------------------------------------------------------------------------------------------------
# Data : b'j\xff\x00\xf6\xf3um_Rm\x14m\x15\xcf\xfe\xab\xe1\xff\x00\xe7\xe4\xc7\xec\x8f\x8d<I\xa3\xfc~\xd5\xbf\xe4\x13\xe1=\x1e\xcf\xfe\xbeu?;\xff\x00i\xc7\\\x86\xbd\xfb=~\xd4\xde?\\\x9f\x11xo\xc3#\xb9\xd3\xad\xbf|?\xef\xff\x00\x99\xff\x00\x90\xeb\xef\x93\x8a\x00\x19\xae\x8f\xf5w\n'.
# Line no. 43, length : 171 and type : <class 'bytes'>.
# -----------------------------------------------------------------------------------------------------------------------------
# Data : b"/eL\xfc\xd5\xb0\xff\x00\x82I|H\xd5\xb5\x7f\xedO\x10x\xe2\xee\xf6\xf7\xaf\xda.n\xa4\x9a\xbd\x7f\xe1\xff\x00\xfc\x13\x83_\xf0\xa8\xff\x00J\xf1\x0e~\x95\xf6\x8e1Ez4r\xdaT\xb65<_\xc0\xdf\xb3M\xcf\x85G\xfaV\xad^\x95\xa5\xf8K\xfb'\xfe^MmQ]\x94\xa8\xd3\xa7\xb0\x04P\xed\x15%\x14V\xc0\x14QE\x00\x14QE\x00\x14QE\x00\x14QE\x00\x14QE\x00\x14QE\x00\x14QE\x00\x14QE\x00\x14QE\x00\x14QE\x00\x14QE\x00\x14QE\x00\x18\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x03\xff\xd9".

# %%
with open('watermelon32x32.jpg', 'rb+') as img_f, open('watermelon_rev.jpg', 'wb+') as img_rev:
    data = img_f.readlines()
    data[16]= bytes([2,17,252,99,87,87,42,83,49])
    img_rev.writelines(data)
# display.Image('watermelon32x32.jpg')
display.Image('watermelon_rev.jpg')

# %%
with open('text_bin.bin', 'wb+') as f:
    f.write(bytes('Python', encoding = 'UTF-8'))

# %%
with open('text_bin.bin', 'rb') as f:
    data = bytearray(f.read())
    for x in range(len(data)):
        print('Python'[x],' ', data[x])
    data[2] = 84

print(data)
# Out:
# P   80
# y   121
# t   116
# h   104
# o   111
# n   110
# bytearray(b'PyThon')

# %%
with open('text_bin_rev.bin', 'wb+') as f:
    f.write(data)

# %%
with open('text_bin_rev.bin', 'a+') as f:
    f.seek(0)
    print(f.read())
# Out:
# PyThon

# %%
with open('animal_jokes.txt', 'r') as f:
    data = f.read(20)
    with open('animal_jokes.txt', 'wb+') as f2:
        for x in data:
            f2.write(bytes(x))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [154], in <cell line: 1>()
#       3 with open('animal_jokes.txt', 'wb+') as f2:
#       4     for x in data:
# ----> 5         f2.write(bytes(x))
#
# TypeError: string argument without an encoding

# %%
f = open('my_file', 'w+b')
byte_arr = [120, 3, 255, 0, 100]
binary_format = bytearray(byte_arr)
f.write(binary_format)
f.close()

# %%
f = open('my_file', 'r')
print(f.read())
# Out:
# xÿd

# %%
import os
os.getcwd()
# os.chdir('C:\\Users\Sony\Downloads\Python study material\Python file handling')
# Out:
# 'C:\\Users\\Sony\\Downloads\\Python study material\\Python file handling'

# %%
data = [100,24,255]
buffer = bytes(data)
print(buffer)
f = open("binary.txt", "bw")
f.write(buffer)
datt=dict(buffer)
print(datt)
# Out:
# b'd\x18\xff'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [15], in <cell line: 6>()
#       4 f = open("binary.txt", "bw")
#       5 f.write(buffer)
# ----> 6 datt=dict(buffer)
#       7 print(datt)
#
# TypeError: cannot convert dictionary update sequence element #0 to a sequence

# %%
data = ['basket_ball',('Ram', 'Raja', 'Kumar')]
buffer = bytes(data)
print(buffer)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [27], in <cell line: 2>()
#       1 data = ['basket_ball',('Ram', 'Raja', 'Kumar')]
# ----> 2 buffer = bytes(data)
#       3 print(buffer)
#
# TypeError: 'str' object cannot be interpreted as an integer

# %%
f = open("binary.txt", "br")
binary = f.read()
print(binary)
data = list(binary)
print(data)
f.close()
# Out:
# b'd\x18\xff'
# [100, 24, 255]

# %%
# Pickling / Unpickling.

# %%
# The Python pickle modulle allows one to save the state of Python objects in a file and re-builds them on load. Therefore,
# user-built classes and objects can be preserved and transferred for re-initialising one the an interpreter is run again. 


ex_dict = {'a':20, 'b': 30, 'c':40}
f = open("binary.txt", "br")
binary = f.read()
print(binary)
data = list(binary)
print(data)
f.close()
    
# To save the above dictionary to a file, one would have to convert everything including the curly braces to a string and
# then while opening - re-convert the key, value pairs into a dictionary.

# Pickle makes it simple.
# Out:
# b'd\x18\xff'
# [100, 24, 255]

# %%
import pickle

with open('dict_file.txt','wb') as f:
    pickle.dump(ex_dict, f)

# %%
with open('dict_file.txt','rb') as f:
    ex_dict = pickle.load(f)

# %%
Given a binary file game.dat, containing records of following list format: [game_name, participants]
Write a function in Python that would read contents from the file game.dat and creates a file named 
basket.dat copying only those records from game.dat where the game name is "Basket Ball"

# %%
# basket_ball = ['raj','kumar','ram']
# cricket = ['tiger','lion', 'damodar']
# chess = ['vishwanath','pragnanda','guru']
# india = [basket_ball,cricket,chess]

country_name = str(input('Enter the country name: '))
country_name = country_name.lower().strip()
key = {india:(basket_ball,chess,kabadi), china:(karate,judo,table_tennis), usa:()}
    
# with open('game.dat','wb+') as f:
# Out:
# Enter the country name:    India
# india

# %%
print(ex_dict)
# Out:
# {'a': 20, 'b': 30, 'c': 40}

# %%
# It can be used with lists, sets, dictionaries, JSON files and any user defined classes and objects.
